# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 150

# %%
a = np.load('acc/Watch_accelerometer_X.npy')

# %%
plt.plot(range(2000000,2001000),a[2000000:2001000])

# %%
a = np.load('pow/active_power.npy')

# %%
plt.plot(range(479000,482000),a[479000:482000])

# %%
a = np.load('gas/HT_Sensor_dataset_0.npy')

# %%
plt.plot(range(600000,605000),a[600000:605000])

# %%
a = np.load('dna/nanopore.npy')

# %%
plt.plot(range(600000,600250),a[600000:600250])

# %%
a = np.load('PPG/S2_BVP.npy')

# %%
plt.plot(range(312400,313800),a[312400:313800])

# %%
a = np.load('siemens/sensordata/sensordata.npy')

# %%
plt.plot(range(600000,602500),a[600000:602500])

# %%
a = np.load('siemens/vibration/vibration.npy')

# %%
plt.plot(range(600000,602500),a[600000:602500])

# %%
a = np.load('gyr/Watch_gyroscope_X.npy')

# %%
plt.plot(range(3001000,3002000),a[3001000:3002000])
